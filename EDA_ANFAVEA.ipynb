# %%
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel (r"C:\Users\jogmo\Downloads\SeriesTemporais_Autoveiculos.xlsm")

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.read_excel( sheet_name="Plan1", skiprows=2, header=None)
#
# TypeError: read_excel() missing 1 required positional argument: 'io'
